# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsingh2006/Prediction-model/blob/main/Sample_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
#
# Cardiovascular disease prediction

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # Project Summary: Cardiovascular Disease Prediction Using Decision Tree Classifier
#
# Cardiovascular disease (CVD) is one of the leading causes of death worldwide and poses a significant challenge to public health systems. Early detection and diagnosis of cardiovascular disease can help healthcare professionals take preventive measures and provide timely treatment, thereby reducing the risk of severe complications. With the growing availability of healthcare data and advancements in machine learning, predictive models can be developed to assist medical practitioners in identifying individuals who are at risk of cardiovascular disease. This project focuses on predicting the presence of cardiovascular disease in individuals using a Decision Tree Classifier, a supervised machine learning algorithm.
#
# The dataset used in this project contains various health-related attributes of individuals, such as age, gender, blood pressure, cholesterol levels, glucose levels, body mass index (BMI), smoking habits, alcohol consumption, physical activity, and other relevant medical indicators. These features serve as the input variables, while the target variable indicates whether an individual is suffering from cardiovascular disease or not. The objective of the project is to analyze the relationship between these health factors and cardiovascular disease and develop a predictive model that can accurately classify individuals into disease-positive or disease-negative categories.
#
# The project begins with data preprocessing and exploratory data analysis (EDA). During this stage, the dataset is examined for missing values, duplicate records, and inconsistencies. Data cleaning techniques are applied to ensure the quality and reliability of the dataset. Statistical summaries and visualizations are used to understand the distribution of features and identify important patterns. Categorical variables are encoded into numerical form where necessary, and the dataset is prepared for machine learning model training.
#
# After preprocessing, the dataset is divided into training and testing sets. The training set is used to train the Decision Tree Classifier, while the testing set is used to evaluate the model's performance on unseen data. A Decision Tree Classifier was selected for this project because of its simplicity, interpretability, and ability to handle both numerical and categorical data. The algorithm works by recursively splitting the dataset into subsets based on the most informative features, creating a tree-like structure that represents decision rules for classification.
#
# The trained model learns patterns from the input features and generates decision paths that help determine whether an individual is likely to have cardiovascular disease. Model performance is evaluated using metrics such as accuracy, precision, recall, and F1-score. These evaluation metrics provide insights into the effectiveness of the model in correctly identifying individuals with and without cardiovascular disease. Additionally, the confusion matrix is analyzed to assess the classification results and identify any misclassifications.
#
# The results demonstrate that machine learning techniques can effectively assist in the prediction of cardiovascular disease. The Decision Tree Classifier provides clear and interpretable decision rules, making it suitable for healthcare-related applications where transparency is important. By identifying key risk factors associated with cardiovascular disease, the model can support healthcare professionals in risk assessment and preventive healthcare planning.
#
# In conclusion, this project highlights the potential of machine learning in the healthcare domain. The developed Decision Tree Classifier successfully utilizes patient health information to predict the likelihood of cardiovascular disease. Such predictive systems can contribute to early diagnosis, improved patient outcomes, and data-driven decision-making in healthcare. Future improvements may include the use of advanced machine learning algorithms such as Random Forest, Gradient Boosting, or XGBoost to further enhance prediction accuracy and robustness. Overall, the project demonstrates how data analytics and machine learning can play a crucial role in addressing real-world healthcare challenges.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
path ='/content/drive/MyDrive/dataset/Copy of data_cardiovascular_risk.csv'

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
#  16  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 450.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull()
# Out:
#          id    age  education    sex  is_smoking  cigsPerDay  BPMeds  \
# 0     False  False      False  False       False       False   False
# 1     False  False      False  False       False       False   False
# 2     False  False      False  False       False       False   False
# 3     False  False      False  False       False       False   False
# 4     False  False      False  False       False       False   False
# ...     ...    ...        ...    ...         ...         ...     ...
# 3385  False  False      False  False       False       False   False
# 3386  False  False      False  False       False       False   False
# 3387  False  False      False  False       False       False   False
# 3388  False  False      False  False       False       False    True
# 3389  False  False      False  False       False       False   False
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0               False         False     False    False  False  False   True
# 1               False         False     False    False  False  False  False
# 2               False         False     False    False  False  False  False
# 3               False         False     False    False  False  False  False
# 4               False         False     False    False  False  False  False
# ...               ...           ...       ...      ...    ...    ...    ...
# 3385            False         False     False    False  False  False  False
# 3386            False         False     False    False  False  False  False
# 3387            False         False     False    False  False  False  False
# 3388            False         False     False    False  False  False  False
# 3389            False         False     False    False  False  False  False
#
#       heartRate  glucose  TenYearCHD
# 0         False    False       False
# 1         False    False       False
# 2         False    False       False
# 3         False    False       False
# 4         False    False       False
# ...         ...      ...         ...
# 3385      False    False       False
# 3386      False    False       False
# 3387      False    False       False
# 3388      False    False       False
# 3389      False    False       False
#
# [3390 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# id                   0
# age                  0
# education           87
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# [link text](https://)Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  3390.000000  3390.000000  3303.000000  3368.000000  3346.000000
# mean   1694.500000    49.542183     1.970936     9.069477     0.029886
# std     978.753033     8.592878     1.019081    11.879078     0.170299
# min       0.000000    32.000000     1.000000     0.000000     0.000000
# 25%     847.250000    42.000000     1.000000     0.000000     0.000000
# 50%    1694.500000    49.000000     2.000000     0.000000     0.000000
# 75%    2541.750000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count      3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# mean          0.006490      0.315339     0.025664   237.074284   132.60118
# std           0.080309      0.464719     0.158153    45.247430    22.29203
# min           0.000000      0.000000     0.000000   107.000000    83.50000
# 25%           0.000000      0.000000     0.000000   206.000000   117.00000
# 50%           0.000000      0.000000     0.000000   234.000000   128.50000
# 75%           0.000000      1.000000     0.000000   264.000000   144.00000
# max           1.000000      1.000000     1.000000   696.000000   295.00000
#
#              diaBP          BMI    heartRate      glucose   TenYearCHD
# count  3390.000000  3376.000000  3389.000000  3086.000000  3390.000000
# mean     82.883038    25.794964    75.977279    82.086520     0.150737
# std      12.023581     4.115449    11.971868    24.244753     0.357846
# min      48.000000    15.960000    45.000000    40.000000     0.000000
# 25%      74.500000    23.020000    68.000000    71.000000     0.000000
# 50%      82.000000    25.380000    75.000000    78.000000     0.000000
# 75%      90.000000    28.040000    83.000000    87.000000     0.000000
# max     142.500000    56.800000   143.000000   394.000000     1.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.select_dtypes(include='object').columns:
    print(f"\n{col}")
    print("Unique Values:", df[col].nunique())
    print(df[col].value_counts())
# Out:
# sex
# Unique Values: 2
# sex
# F    1923
# M    1467
# Name: count, dtype: int64
#
# is_smoking
# Unique Values: 2
# is_smoking
# NO     1703
# YES    1687
# Name: count, dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df['sex'] = np.where(df['sex'] == 'F', 1, 0)

# %%
df['is_smoking'] = np.where(df['is_smoking'] == 'YES', 1, 0)

# %%
df['is_smoking'].value_counts()
# Out:
# is_smoking
# 0    1703
# 1    1687
# Name: count, dtype: int64

# %%
df['diabetes'].value_counts()
# Out:
# diabetes
# 0    3303
# 1      87
# Name: count, dtype: int64

# %%
x = df.drop(columns=['diabetes'])
y = df['diabetes']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
model = DecisionTreeClassifier(max_depth=10,
    random_state=42)

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=42)

# %%
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

# %%
train_pred = model.predict(x_train)
train_pred = np.where(train_pred>0.5,1,0)
train_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score
print('Train Confusion Matrix \n',confusion_matrix(y_train,train_pred))
print('Train Accuracy ',accuracy_score(y_train,train_pred))
print('Train Precision ',precision_score(y_train,train_pred))
print('Train Recall ',recall_score(y_train,train_pred))
# Out:
# Train Confusion Matrix
#  [[2640    0]
#  [   6   66]]
# Train Accuracy  0.9977876106194691
# Train Precision  1.0
# Train Recall  0.9166666666666666

# %%
print('Test Confusion Matrix \n', confusion_matrix(y_test,test_pred))
print('Test Accuracy ',accuracy_score(y_test,test_pred))
print('Test Precision ',precision_score(y_test,test_pred))
print('Test Recall ',recall_score(y_test,test_pred))
# Out:
# Test Confusion Matrix
#  [[655   8]
#  [  8   7]]
# Test Accuracy  0.976401179941003
# Test Precision  0.4666666666666667
# Test Recall  0.4666666666666667

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.
# The key metric for positive business and healthcare impact was Recall, supported by F1-Score, Precision, Accuracy, and Confusion Matrix analysis. A high Recall ensures that most cardiovascular disease cases are detected early, contributing to better patient care, reduced medical risks, and improved healthcare decision-making.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.
# Among the various machine learning models evaluated, the Decision Tree Classifier was selected as the final prediction model for cardiovascular disease prediction.
#
# The primary reason for choosing the Decision Tree Classifier is its interpretability and ease of understanding. Unlike many complex machine learning algorithms, a decision tree provides a clear visualization of the decision-making process, making it easier to identify which health factors contribute most to the prediction of cardiovascular disease. This transparency is particularly important in healthcare applications, where understanding the reasoning behind predictions is crucial.
#
# Additionally, the Decision Tree Classifier demonstrated strong performance on the evaluation metrics, including Accuracy, Precision, Recall, and F1-Score. The model was able to capture non-linear relationships among the features and effectively classify individuals based on their health characteristics.
#
# The key advantages that led to its selection include:
#
# High predictive performance on the testing dataset.
# Easy interpretation and visualization of decision rules.
# Ability to handle both numerical and categorical features.
# Minimal data preparation requirements compared to some other algorithms.
# Useful feature importance analysis for identifying major cardiovascular risk factors.
#
# Although more advanced models such as Random Forest or Gradient Boosting may achieve slightly higher accuracy, the Decision Tree Classifier offers an excellent balance between performance, simplicity, and interpretability. Therefore, it was chosen as the final model for predicting whether an individual is likely to suffer from cardiovascular disease.
#
# Final Selected Model: Decision Tree Classifier
#
# Reason for Selection: Best combination of predictive performance, interpretability, ease of implementation, and suitability for healthcare decision support.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.
# The Decision Tree Classifier was selected because it provides both good predictive performance and excellent interpretability. Using Feature Importance and SHAP explainability techniques, the model's predictions can be clearly understood, making it suitable for healthcare applications where transparency and trust are essential.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
# This project successfully developed a machine learning-based system to predict the presence of cardiovascular disease using a Decision Tree Classifier. By analyzing various health-related factors such as age, blood pressure, cholesterol levels, glucose levels, BMI, smoking habits, alcohol consumption, and physical activity, the model was able to identify patterns associated with cardiovascular disease risk.
#
# The dataset was preprocessed through data cleaning, handling missing values, removing duplicates, and performing exploratory data analysis to ensure data quality. The Decision Tree Classifier was then trained and evaluated using appropriate performance metrics such as Accuracy, Precision, Recall, F1-Score, and Confusion Matrix. The results demonstrated that the model can effectively classify individuals as having or not having cardiovascular disease.
#
# One of the major advantages of the selected model is its interpretability. Through feature importance analysis, the most influential risk factors contributing to cardiovascular disease prediction were identified, making the model transparent and easy to understand. This is particularly valuable in healthcare applications, where explainable predictions are essential for building trust and supporting clinical decision-making.
#
# The project highlights the potential of machine learning in assisting healthcare professionals with early disease detection and risk assessment. Early identification of high-risk individuals can enable timely medical intervention, improve patient outcomes, and reduce healthcare costs associated with advanced-stage cardiovascular complications.
#
# In conclusion, the developed Decision Tree model provides an effective and interpretable approach for cardiovascular disease prediction. Future work may involve using advanced ensemble techniques such as Random Forest, XGBoost, or Gradient Boosting to further improve predictive performance and model robustness. Overall, this project demonstrates how machine learning can be leveraged to support data-driven healthcare solutions and contribute to better preventive care strategies.
#
# > Add blockquote

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
